# %% [markdown]
# <a href="https://colab.research.google.com/github/mammot41038-beep/mammothAT/blob/main/HorizonQ_DeepTrain_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import subprocess
ret = subprocess.call(['bash', '-c', 'wget -O  horizon_q_deeptrain_colab.py https://raw.githubusercontent.com/HorizonQ-Lab/horizon-q-colab-trainer/main/horizon_q_deeptrain_colab.py'])

# %%
# %run horizon_q_deeptrain_colab.py
